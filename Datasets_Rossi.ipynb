# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosARossi/dataScienceCoder/blob/main/Datasets_Rossi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Datasets con la librería Pandas

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/1- Profesional/0- Cursos/7-CoderHouse-DataScience/Datasets-Rossi
# Out:
# /content/drive/MyDrive/1- Profesional/0- Cursos/7-CoderHouse-DataScience/Datasets-Rossi

# %% [markdown]
# ## Opción 1 - Salarios
# Fuente: https://www.kaggle.com/datasets/ricardoaugas/salary-transparency-dataset-2022

# %%
dataset1 = pd.read_csv('Salary_Data_2022_REV15 2.csv')
dataset1
# Out:
#           ID        Timestamp Age.Range  Years.of.Experience  \
# 0          1   12/8/2021 3:05     18-21                  3.0
# 1          2  12/9/2021 15:49     30-33                  5.0
# 2          3   12/8/2021 2:16     18-21                  1.0
# 3          4   12/8/2021 5:15     18-21                  2.0
# 4          5  12/8/2021 14:16     34-37                 13.0
# ...      ...              ...       ...                  ...
# 32565  32566    1/7/2022 2:27     30-33                  9.0
# 32566  32567    1/7/2022 6:09     34-37                 14.0
# 32567  32568   1/7/2022 12:38     30-33                  5.0
# 32568  32569   1/7/2022 12:40     26-29                  4.0
# 32569  32570   1/7/2022 12:41     22-25                  3.0
#
#                 Industry                                    Job.Title  \
# 0                 GAMING                                     STREAMER
# 1             HEALTHCARE  AESTHETIC NURSE PRACTITIONER/BUSINESS OWNER
# ...

# %%
dataset1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32570 entries, 0 to 32569
# Data columns (total 24 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   ID                                                               32570 non-null  int64
#  1   Timestamp                                                        32570 non-null  object
#  2   Age.Range                                                        32549 non-null  object
#  3   Years.of.Experience                                              32053 non-null  float64
#  4   Industry                                                         32355 non-null  object
#  5   Job.Title                                                        32566 non-null  object
#  6   Company.Name                                                     32568 non-null  object
# ...

# %%
dataset1.describe()
# Out:
#                 ID  Years.of.Experience         Salary  Annual.Bonus  \
# count  32570.00000         32053.000000   32570.000000  3.257000e+04
# mean   16285.50000             4.321842   77056.813233  6.573224e+03
# std     9402.29347             3.384184   46032.041714  8.961993e+04
# min        1.00000             1.000000       0.000000  0.000000e+00
# 25%     8143.25000             2.000000   50000.000000  0.000000e+00
# 50%    16285.50000             3.000000   69700.000000  0.000000e+00
# 75%    24427.75000             6.000000   93000.000000  4.000000e+03
# max    32570.00000            19.000000  490000.000000  1.500000e+07
#
#        Annual.Average.of.RSUs  Signing.Bonus     Sick.Days   Office.Days    X
# count            3.257000e+04   3.257000e+04  17703.000000  17964.000000  0.0
# mean             1.175429e+04   1.636194e+03      7.783255      3.779448  NaN
# std              1.607390e+06   1.195543e+04     13.232988      1.454159  NaN
# ...

# %% [markdown]
# ### Contexto comercial:
# Este dataset podría ser utilizado por las empresas para analizar los salarios en diferentes áreas y para identificar desigualdades salariales. También podría ser utilizado por los empleados para comparar sus salarios con los de sus colegas y para negociar aumentos salariales.

# %% [markdown]
# ### Contexto analítico:
# Los analísis que se pueden realizar con las variables disponibles, entre otros, son:
# 1. Comparar los rangos salariales de un mismo puedo en diferentes tipos de industria.
# 2. Validar si el nivel de educación alcanzado tiene alguna incidencia sobre los salarios.
# 3. Medir la diversidad de genero por cada puesto y la relación salarial.

# %% [markdown]
# ## Opción 2 - Catálogo de productos
# Fuente: https://data.world/crawlfeeds/ecommerce-datasets

# %%
dataset2 = pd.read_csv('amazon_products_data.csv')
dataset2
# Out:
#                                        rl        asin  \
# 0     https://www.amazon.in/dp/1788832566  1788832566
# 1     https://www.amazon.in/dp/0766199592  0766199592
# 2     https://www.amazon.in/dp/B071ZCD9XH  B071ZCD9XH
# 3     https://www.amazon.in/dp/B00IG6EML8  B00IG6EML8
# 4     https://www.amazon.in/dp/1637583060  1637583060
# ...                                   ...         ...
# 1431  https://www.amazon.in/dp/1093595124  1093595124
# 1432  https://www.amazon.in/dp/B098MJJLD9  B098MJJLD9
# 1433  https://www.amazon.in/dp/1720297185  1720297185
# 1434  https://www.amazon.in/dp/0393091538  0393091538
# 1435  https://www.amazon.in/dp/0578737191  0578737191
#
#                                                    name overview     price  \
# 0     Hands-On Design Patterns with C++: Solve commo...       []  1,600.00
# 1     The Blazing Horizon The True Story of Pawnee B...       []  2,399.00
# 2     Fast and easy lunch box: A collection of 15eas...       []       NaN
# ...

# %%
dataset2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 17 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   rl                1436 non-null   object
#  1   asin              1436 non-null   object
#  2   name              1435 non-null   object
#  3   overview          1436 non-null   object
#  4   price             1092 non-null   object
#  5   currency          1092 non-null   object
#  6   availability      959 non-null    object
#  7   brand             1426 non-null   object
#  8   about_item        119 non-null    object
#  9   img_source        1436 non-null   object
#  10  description       108 non-null    object
#  11  specifications    1407 non-null   object
#  12  primary_category  1436 non-null   object
#  13  category_1        1436 non-null   object
#  14  category_2        1218 non-null   object
#  15  category_3        96 non-null     object
# ...

# %%
dataset2.describe()
# Out:
#                                          rl        asin  \
# count                                  1436        1436
# unique                                 1436        1436
# top     https://www.amazon.in/dp/1788832566  1788832566
# freq                                      1           1
#
#                                                      name overview   price  \
# count                                                1435     1436    1092
# unique                                               1435       24     857
# top     Hands-On Design Patterns with C++: Solve commo...       []  399.00
# freq                                                    1     1413      12
#
#        currency availability           brand  \
# count      1092          959            1426
# unique        1           15            1336
# top         INR    In stock.  Brand: Generic
# freq       1092          479              33
#
#                                                about_item  \
# ...

# %% [markdown]
# ### Contexto comercial:
# Los datos del catálogo de productos de un ecommerce con información como el nombre del producto, precio, marca y categorías son valiosos para mejorar la experiencia del usuario en el sitio web de ecommerce, personalizar la experiencia del usuario y dirigir campañas publicitarias a los clientes adecuados.

# %% [markdown]
# ### Contexto analítico:
# Los analísis que se pueden realizar con las variables disponibles, entre otros, son:
# 1. Categorías: analizar las categorías de productos que son más populares y cuáles son las menos populares.
# 2. Precio/stock: analizar la relación entre el precio y la disponibilidad del producto, y con esto determinar a cuales productos hay que aumentar su exposición para que tengan mas rotación.
# 3. Predecir la popularidad de ciertos productos y optimizar la oferta y disponibilidad en función de la demanda.

# %% [markdown]
# ## Opción 3 - Series y películas de Amazon Prime
# Fuente: https://www.kaggle.com/datasets/dgoenrique/amazon-prime-movies-and-tv-shows?select=titles.csv

# %%
dataset3 = pd.read_csv('titlesAmazon.csv')
dataset3
# Out:
#               id                               title   type  \
# 0        tm87233               It's a Wonderful Life  MOVIE
# 1       tm143047                           Duck Soup  MOVIE
# 2        tm83884                     His Girl Friday  MOVIE
# 3        ts20945                   The Three Stooges   SHOW
# 4         tm5012                           Red River  MOVIE
# ...          ...                                 ...    ...
# 10868  tm1292884                                Hunt  MOVIE
# 10869  tm1284753                  Ennalum Ente Aliya  MOVIE
# 10870  tm1303380  Anubhav Singh Bassi: Bas Kar Bassi  MOVIE
# 10871  tm1307408     Pinkfong! Summer in Wonderville  MOVIE
# 10872  tm1297385                            Chapelle  MOVIE
#
#                                              description  release_year  \
# 0      A holiday favourite for generations...  George...          1946
# 1      Rufus T. Firefly is named president/dictator o...          1933
# ...

# %%
dataset3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10873 entries, 0 to 10872
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10873 non-null  object
#  1   title                 10873 non-null  object
#  2   type                  10873 non-null  object
#  3   description           10729 non-null  object
#  4   release_year          10873 non-null  int64
#  5   age_certification     3688 non-null   object
#  6   runtime               10873 non-null  int64
#  7   genres                10873 non-null  object
#  8   production_countries  10873 non-null  object
#  9   seasons               1551 non-null   float64
#  10  imdb_id               10172 non-null  object
#  11  imdb_score            9765 non-null   float64
#  12  imdb_votes            9753 non-null   float64
#  13  tmdb_popularity       10302 non-null  float64
#  14  tmdb_score            8747 non-null   float64
# ...

# %%
dataset3.describe()
# Out:
#        release_year       runtime      seasons   imdb_score    imdb_votes  \
# count  10873.000000  10873.000000  1551.000000  9765.000000  9.753000e+03
# mean    2004.077807     85.869033     2.661509     5.970558  8.973232e+03
# std       24.883711     34.156332     3.719633     1.362815  4.897767e+04
# min     1912.000000      0.000000     1.000000     1.100000  5.000000e+00
# 25%     2002.000000     65.000000     1.000000     5.100000  1.190000e+02
# 50%     2015.000000     89.000000     1.000000     6.100000  4.880000e+02
# 75%     2019.000000    102.000000     3.000000     7.000000  2.493000e+03
# max     2023.000000    940.000000    53.000000     9.900000  2.081757e+06
#
#        tmdb_popularity   tmdb_score
# count     10302.000000  8747.000000
# mean          7.614083     5.977729
# std          45.845289     1.512941
# min           0.000153     0.500000
# 25%           1.327250     5.066500
# 50%           2.658500     6.000000
# 75%           6.185000     6.983000
# ...

# %% [markdown]
# ### Contexto comercial:
# Los datos de los programas y películas disponibles en Amazon Prime, como el título, el año de lanzamiento, la calificación por edades y la duración, son valiosos para la presentación de contenido a los usuarios y para la segmentación de audiencias.
# Los datos también pueden ser utilizados para tomar decisiones informadas sobre la adquisición de derechos de contenido y la inversión en nuevas producciones de contenido.

# %% [markdown]
# ### Contexto analítico:
# Los analísis que se pueden realizar con las variables disponibles, entre otros, son:
# 1. Realizar análisis y estudios de mercado sobre el comportamiento del usuario y las tendencias del mercado.
# 2. Identificar patrones en la selección de contenido y las preferencias del usuario.
# 3. Predecir la popularidad de nuevos programas y películas y optimizar la oferta de contenido.
